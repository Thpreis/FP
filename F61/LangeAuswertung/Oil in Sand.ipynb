# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.optimize import curve_fit

# %%
from scipy.signal import savgol_filter

# %%
x, y = np.loadtxt('27.03.18/OilSand.txt', usecols = (0, 1), unpack = True) #x in mm and y in arbitrary units
#x1, y1 = np.loadtxt('27.03.18/OilSand1.txt', usecols = (0, 1), unpack = True)
#x2, y2 = np.loadtxt('27.03.18/OilSand2.txt', usecols = (0, 1), unpack = True)
#x3, y3 = np.loadtxt('27.03.18/OilSand3.txt', usecols = (0, 1), unpack = True)
#x4, y4 = np.loadtxt('27.03.18/OilSand4.txt', usecols = (0, 1), unpack = True)
x5, y5 = np.loadtxt('27.03.18/OilSand5.txt', usecols = (0, 1), unpack = True)
#x6, y6 = np.loadtxt('27.03.18/OilSand6.txt', usecols = (0, 1), unpack = True)
#x7, y7 = np.loadtxt('27.03.18/OilSand7.txt', usecols = (0, 1), unpack = True)
#x8, y8 = np.loadtxt('27.03.18/OilSand8.txt', usecols = (0, 1), unpack = True)
#x9, y9 = np.loadtxt('27.03.18/OilSand9.txt', usecols = (0, 1), unpack = True)
x10, y10 = np.loadtxt('27.03.18/OilSand10.txt', usecols = (0, 1), unpack = True)
#x11, y11 = np.loadtxt('27.03.18/OilSand11.txt', usecols = (0, 1), unpack = True)
#x12, y12 = np.loadtxt('27.03.18/OilSand12.txt', usecols = (0, 1), unpack = True)
#x13, y13 = np.loadtxt('27.03.18/OilSand13.txt', usecols = (0, 1), unpack = True)
#x14, y14 = np.loadtxt('27.03.18/OilSand14.txt', usecols = (0, 1), unpack = True)
x15, y15 = np.loadtxt('27.03.18/OilSand15.txt', usecols = (0, 1), unpack = True)
#x16, y16 = np.loadtxt('27.03.18/OilSand16.txt', usecols = (0, 1), unpack = True)
#x17, y17 = np.loadtxt('27.03.18/OilSand17.txt', usecols = (0, 1), unpack = True)
#x18, y18 = np.loadtxt('27.03.18/OilSand18.txt', usecols = (0, 1), unpack = True)
x19, y19 = np.loadtxt('27.03.18/OilSand19.txt', usecols = (0, 1), unpack = True)
plt.plot(x,savgol_filter(y, 61, 3, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0), lw=0.5,label="t=0 s")
#plt.plot(x1,y1, lw=0.5)
#plt.plot(x2,y2, lw=0.5)
#plt.plot(x3,y3, lw=0.5)
#plt.plot(x4,y4, lw=0.5)
plt.plot(x5,savgol_filter(y5, 61, 3, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0), lw=0.5,label="t=10 min")
#plt.plot(x6,y6, lw=0.5)
#plt.plot(x7,y7, lw=0.5)
#plt.plot(x8,y8, lw=0.5)
#plt.plot(x9,y9, lw=0.5)
plt.plot(x10,savgol_filter(y10, 61, 3, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0), lw=0.5, label="t=20 min")
#plt.plot(x11,y11, lw=0.5)
#plt.plot(x12,y12, lw=0.5)
#plt.plot(x13,y13, lw=0.5)
#plt.plot(x14,y14, lw=0.5)
plt.plot(x15,savgol_filter(y15, 61, 3, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0), lw=0.5,label="t=30 min")
#plt.plot(x16,y16, lw=0.5)
#plt.plot(x17,y17, lw=0.5)
#plt.plot(x18,y18, lw=0.5)
plt.plot(x19,savgol_filter(y19, 61, 3, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0), lw=0.5, label="t=38 min")
plt.xlabel("Height in glass tube [mm]")
plt.ylabel("Intensity [a.u.]")
plt.xlim(-18.,13.3)
plt.legend(loc="best")
plt.savefig("AccumulatedOilSand.pdf")

# %%
x20, y20 = np.loadtxt('27.03.18/Oil15mm.txt', usecols = (0, 1), unpack = True) #x in mm and y in arbitrary units
x21, y21 = np.loadtxt('27.03.18/Oil50mm.txt', usecols = (0, 1), unpack = True)
plt.plot(x20,savgol_filter(y20, 61, 3, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0), label="15mm Oil", lw=0.8)
plt.plot(x21,savgol_filter(y21, 61, 3, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0), label="50mm Oil", lw=0.8)
plt.xlabel("Height in glass tube [mm]")
plt.ylabel("Intensity [a.u.]")
plt.ylim(0.,140.)
plt.legend(loc="upper center")
plt.savefig("1DOilSamples.pdf")

# %%
x22, y22 = np.loadtxt('27.03.18/oiltef.txt', usecols = (0, 1), unpack = True) #x in mm and y in arbitrary units
plt.plot(x22,y22, lw=0.8)
plt.xlabel("Height in glass tube [mm]")
plt.ylabel("Intensity [a.u.]")
plt.xlim(-10.,13.)
plt.savefig("OilTef.pdf")
